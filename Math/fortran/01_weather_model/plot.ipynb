# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
weather_df = pd.read_csv('./weather.csv')
weather_df.index = weather_df[' Day']
weather_df.drop(columns=[' Day']).plot.line()
# Out:
# <Axes: xlabel=' Day'>
